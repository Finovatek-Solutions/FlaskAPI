# %% [markdown]
# Importing Python packages

# %%
from openai import OpenAI
import pandas as pd

# %% [markdown]
# Creating data structures and validating API key
#
# descriptions is a list that contains the descriptions of all bank transactions in CSV
#
# results is a list that contains the content of the model response

# %%
df = pd.read_csv(r"C:\Users\aj824\OneDrive - University of Puerto Rico\Classes\INSO4151 (Capstone)\FlaskAPI\OpenAI API\banco popular personal - banco popular personal.csv", delimiter=",")

descriptions = df["Description"].to_list()
results = []
client = OpenAI(api_key = "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")

# %% [markdown]
# For loop that sends a request to the model and stores the response in results

# %%
for description in descriptions:
    completion = client.chat.completions.create(
        model="ft:gpt-3.5-turbo-0125:finovatek-solutions:capstone:8zp7M20L",
        messages=[
            {"role": "system", "content": "Classify the bank transaction type based on the description given. If not, leave it blank"},
            {"role": "user", "content": "Classify the following bank transaction: " + description}
        ]
        )
    results.append(completion.choices[0].message.content)
    print(completion.choices[0].message.content)
# Out:
# Online Purchases
# Credit Card Payments
# Credit Card Payment
# Fiduciary Fees
# Insurance
# Health
# Credit Card Payments
# In some cases, transactions identified as "Cheque" can be classified as "Generic Expense" or "Checks"
# Withdrawals
# Health
# Bills > Utilities
# Health
# Credit Card Payment
# Credit Card Payment
# Online Purchases
# Health
# Technology
# Technology
# Technology
# Online Purchases
# Income
# Health
# Technology
# Insurance
# Health
# Technology
# Deposits
# Health
# In this case, we would need more information to correctly classify the transaction.
# Fees
# Income:Interests
# Health
# Fiduciary Funds
# Health
# Deposits
# Insurance
# Health Care
# Bills - Utilities
# Online Payments
# Personal Expenses
# Technology
# Deposits
# Personal Expenses
# Health
# Insurance
# Personal Expenses
# Health
# Fees
# Personal Expenses
# Technology
# Credit Card Payments
# Credit Card Payments
# In this case, the bank transaction type would be left blank, as there is not enough information to classify it.
# Payments by Check
# In this case, the bank transaction type would be "Income".
# Withdrawals
# Bank Fees
# Technology
# Fiduciary fees
# Technology
# Personal Expenses
# Technology
# Online Purchases
# Online Purchases
# Personal Expenses
# Insurance
# Health
# Online Purchases
# Check
# Technology
# Personal Expenses
# Online Purchases
# Technology
# Utilities
# Personal Expenses
# Health
# Phone
# Deposits
# Practice Incomes
# Practice Incomes
# Insurance
# Practice Incomes
# Technology
# Deposits
# Income
# In this case, the bank transaction can be classified as "Cheque Deposit"
# Deposits
# Personal Expenses
# Insurance
# Check
# Income
# Health
# Deposits
# Insurance
# Online Purchases
# Deposits
# Technology
# Practice Incomes
# Fees
# Practice Incomes
# Utilities
# Deposits
# Practice Incomes
# In this case, we'll leave it blank.
# Utilities
# Income
# Credit Card Rewards
# Withdrawals
# Withdrawals
# blank
# Insurance
# Deposits
# Healthcare
# Practice Incomes
# Deposits
# Technology
# Deposits
# Credit Card Payments
# Credit Card Payment
# Fees
# Deposits
# Personal Expenses
# Practice Incomes
# Personal Expenses
# Insurance
# Credit Card Payment
# Sync to Payments
# Deposits
# Utilities
# In this case, I would leave it blank as it is not possible to determine the type of transaction from the description "CHEQUE NUMERO 1846" alone.
# Payments by Check
# Personal Expenses
# Health
# Phone Bill
# Bills, Checks & Fees
# Transfers
# Transfers
# Fees
# Ingresos
# Deposits
# Deposits
# Deposits
# Fees
# Check
# Deposits
# Rewards Incentives
# Technology
# Insurance
# Deposits
# Deposits
# Ingreso de efectivo
# Personal Expenses
# Deposits
# Cashback Rewards
# Practice Incomes
# Credit Card Rewards
# Practice Incomes
# Interest Incomes
# Health
# Credit Card Payment
# Fiduciary Account Deposit
# Insurance
# Health Insurances
# Credit Card Payment
# Credit Card Payment
# Deposits
# Credit Card Payments
# Deposits
# Bills - Utilities
# Practice Incomes
# Car Expenses
# Health
# Technology
# Credit Card Payments
# Insurance
# In this case, since the description does not provide enough information to classify the bank transaction, I will leave it blank.
# Credit Card Payments
# Credit Card Payments
# Bill Payments
# Technology
# Personal Expenses
# Credit Card Payment
# Bank Fees
# Income
# Credit Card Payments
# Credit Card Payments
# Technology
# Transfers
# Deposits
# Credit Card Payments
# Cashback Rewards
# Insurance
# Deposits
# Car Expenses
# Transfers
# Bills > Utilities
# Health
# Credit Card Payment
# Digital Payments
# Practice Incomes
# Credit Card Payment
# Credit Card Payment
# Deposits
# Transfers
# Health
# Insurance
# Fees
# Credit Card Payments
# Credit Card Payment
# Utilities
# Technology
# Credit Card Payments
# Fees
# Income
# Deposits
# Credit Card Payments
# Technology
# Bank Fees
# Credit Card Payments
# Payments by Check
# Deposits
# Health
# Payroll
# Insurance
# Personal Expenses
# Credit Card Payments
# Credit Card Payments
# Bills \ Utilities
# Household Expenses
# Credit Card Payments
# Refunds
# Credit Card Payments
# Credit Card Payments
# Personal Expenses
# Car Expenses
# Transfers
# Cash Back Rewards
# Bills / Utilities
# Car Expenses
# Practice Incomes
# Deposits
# In this case, the bank transaction type corresponds to "EFT" payments.
# Bank Fees
# Credit Card Payments
# Credit Card Payments
# Insurance
# Transfers
# Deposits
# Credit Card Payments
# Credit Rewards
#
# Credit Card Payment
# Insurance
# Deposits
# Transfers
# Online Transactions
# Fees
# Deposits
# Health
# Credit Card Payments
# Transfers
# Insurance
# Health Insurance
# Deposits
# Credit Card Payments
# Online Payments
# Fees
# Cash Withdrawal
# Deposits
# Fees
# Other
# Household Expenses
# Utilities
# Health
# Phone Expenses
# Car Expenses
# Credit Card Payments
# Credit Card Payment
# Technology
# Deposits
# Ingresos
# Health
# Personal Expenses
# In this case, the transaction type would be: Checks
# Deposits
# Health Insurance
# Personal Expenses
# Credit Card Payments
# Bank Fees
# Deposits
# Insurance
# Health
# Credit Card Payments
# Credit Card Payments
# Taxes
# Taxes
# Credit Card Payments
# Check
# Car Expenses
# Health
# Technology
# Technology
# Income
# Deposits
# In this case, the bank transaction does not provide enough information to classify it into a specific category.
# Deposits
# Health Insurance
# Insurance
# Ingresos
# Credit Card Payments
# Fees
# Reimbursements
# Utilities
# Online Purchases
# Technology
# Car Expenses
# Credit Card Payments
# Deposits
# Deposits
# Mobile Payment
# Credit Card Payments
# Insurance
# Household Expenses
# Transfers
# Deposits
# Cash Back Rewards
# Car Expenses
# Credit Card Payments
# Transfers
# Transfers
# Deposits
# Incomes
# Deposits
# Interest Incomes
# Deposits
# Car Expenses
# Fees
# Health Insurance
# Health
# Deposits
# Empty
# Insurance
# Deposits
# Health Insurance
# Deposits
# Utilities
# Health
# Deposits
# Credit Card Payments
# Taxes
# Healthcare Payments
# Bank Fees
# In this case, the bank transaction type is a payment by check.
# Deposits
# Deposits
# Credit Card Payments
# Credit Card Payments
# Credit Card Payment
# Insurance
# Technology
# Technology
# Credit Card Payments
# Ingresos
# Health Insurance
# Ingresos por Intereses
# Deposits
# Credit Card Payments
# In this case, the bank transaction type would be "Cheque".
# Insurance
# Credit Card Payments
# Health
# Deposits
# Credit Card Payments
# Car Expenses
# Credit Card Payments
# Credit Card Payments
# Car Expenses
# Utilities
# Health
# Deposits
# Health
# Credit Card Rewards
# Deposits
# Personal Expenses
# Credit Card Payments
# Technology
# Insurance
# Transfers
# Deposits
# Transfers
# Transfers
# Personal Expenses
# Cash Back Rewards
# Cash Back Rewards
# Interest Incomes

# %% [markdown]
# Storing the results in a new Dataframe column called Category and saving it as a new CSV file

# %%
df['Category'] = results
df.head()
# Out:
#        Date                         Description  Amount              Category
# 0  8/1/2022          ATH MOVIL 0209 ON 07/30/22  -455.0      Online Purchases
# 1  8/1/2022  TELEPAGO MASTER CARD BANCO POPULAR -2500.0  Credit Card Payments
# 2  8/1/2022  TELEPAGO MASTER CARD BANCO POPULAR -1000.0   Credit Card Payment
# 3  8/3/2022            FID INST GUAR NA PAYMENT   250.0        Fiduciary Fees
# 4  8/5/2022          LINCOLN NATLIFE PREMPAYMNT  -500.0             Insurance

# %%
df.to_csv('test.csv', index=False)
